# %% [markdown]
# <a href="https://colab.research.google.com/github/mvharsh/Applied-Statistics-with-Python/blob/main/Correlation_Coefficient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Correlation Coefficient**

# %%
import numpy as np
from matplotlib import pyplot
import pandas as pd
import math
import seaborn as sb

# %%
#Function for finding standard deviation of x

def standard_deviation_x(data_x,mean_x,no_of_terms):
    return math.sqrt(sum(np.square(data_x-mean_x)/(no_of_terms-1)))

# %%
#Function for finding standard deviation of y

def standard_deviation_y(data_y,mean_y,no_of_terms):
    return math.sqrt(sum(np.square(data_y-mean_y)/(no_of_terms-1)))

# %%
#Function for finding covariance

def sample_covariance(data_x,mean_x,data_y,mean_y,no_of_terms):
    num= sum(np.subtract(data_x,mean_x)*np.subtract(data_y,mean_y))
    return num/(no_of_terms-1)

# %%
#Function for finding correlation coefficient

def correlation_coefficient(data_x,mean_x,data_y,mean_y,no_of_terms):
    s_xy=sample_covariance(data_x,mean_x,data_y,mean_y,no_of_terms)
    s_x=standard_deviation_x(data_x,mean_x,no_of_terms)
    s_y=standard_deviation_y(data_y,mean_y,no_of_terms)
    correlation= s_xy/(s_x*s_y)
    return correlation

# %%
#Read data from file
data = pd.read_csv('Corelation_Data.xls')
data.head()
# Out:
#    X   Y
# 0  2  50
# 1  5  57
# 2  1  41
# 3  3  54
# 4  4  54

# %%
#Plotting Correlation heat map
dataplot = sb.heatmap(data.corr(), cmap="RdBu", annot=True)

# %% [markdown]
# # **Formulae**

# %% [markdown]
# ***Formula for Standard deviation:***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Formula for Covariance:***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Formula for Correlation Coefficient:***
#
# ![image.png](data:image/png;base64,...)
